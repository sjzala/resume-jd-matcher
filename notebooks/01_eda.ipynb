# %% [markdown]
# # 01 - EDA
#
# Token and length distributions for the seed JD/resume corpus, top n-grams by document, and skill-token coverage. Populated with real cells once the curated dataset stabilises (see docs/data_card.md).
