# %% [markdown]
# # 03 - Error Analysis
#
# Manual review of the worst-ranked positives and false-positive top-1 hits per stage (TF-IDF, bi-encoder, cross-encoder). Tag failure modes (skill aliasing, seniority confusion, domain shift) and feed back into the seed corpus or skill seed list.
