# %% [markdown]
# # 02 - Embedding Experiments
#
# Compare bi-encoder checkpoints (all-MiniLM-L6, all-mpnet-base-v2, bge-small-en-v1.5) on the eval set. Record encode latency on CPU, NDCG@5, and retrieval recall@20. Decisions to update ADR 001 if a better trade-off emerges.
